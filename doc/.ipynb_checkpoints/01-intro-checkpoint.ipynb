# %% [markdown]
# # QA automation
# ---

# %% [markdown]
# ## Definición

# %% [markdown]
# * Es el uso de software especializado para ejecutar pruebas predefinidas en una aplicación sin intervención humana
# * Este método compara los resultados reales con los esperados de forma rápida y repetitiva
# * Es clave para superar desafíos en el desarrollo ágil de software, para lograr productos de calidad y eficiencia

# %% [markdown]
# ## Objetivos

# %% [markdown]
# * Validar funcionalidades
# * Detectar errores
# * Garantizar el rendimiento del software de forma rápida y eficiente
# * Fortalecer el Aseguramiento de Calidad durante todo el ciclo de desarrollo

# %% [markdown]
# ## Beneficios Principales

# %% [markdown]
# * **Ahorro de tiempo**: ejecución rápida de tareas repetitivas y pruebas en paralelo
# * **Mayor precisión**: menor cantidad de errores humanos al revisar procesos complejos
# * **Cobertura constante**: ideal para pruebas de regresión cada vez que el código cambia
# * **Importante para CI/CD**
# * Permite que los tester se enfoquen en pensar escenarios nuevos y conocer más el negocio

# %% [markdown]
# ## Tipos de Pruebas Automatizadas

# %% [markdown]
# * **Pruebas unitarias**: revisa pequeñas partes o funciones del código de manera aislada
# * **Pruebas de integración**: verifica que distintos módulos funcionen bien juntos
# * **Pruebas funcionales/UI/E2E**: simula las acciones de un usuario real (como clics y formularios) en la interfaz
# * **Pruebas de APIs**: se enfoca en validar endpoints y servicios sin necesidad de interfaz gráfica
# * **Pruebas de rendimiento**: analiza cómo se comporta el sistema bajo distintas condiciones
# * **Pruebas de regresión**: se utiliza para asegurar que los cambios en el código no rompen funcionalidades existentes

# %% [markdown]
# ## Pirámide de Pruebas Automatizadas (de Cohn)

# %% [markdown]
# ![piramide.png](attachment:adc49504-9f35-4c01-a76d-fadb840ff12c.png)

# %% [markdown]
# * Sugiere que las pruebas unitarias formen la base de la pirámide, seguidas por las pruebas de integración en el medio, y las pruebas de interfaz de usuario (UI), incluyendo las pruebas end to end (e2e), en el nivel superior
# * Este modelo ayuda a los equipos de desarrollo a enfocarse en escribir más pruebas a nivel de código y menos pruebas a través de la interfaz gráfica de usuario, optimizando así el rendimiento y la calidad del software

# %% [markdown]
# ## Funciones principales de un QA Tester

# %% [markdown]
# * Comprensión de los requisitos del producto o proyecto
# * Diseño de estrategias de prueba eficientes
# * Redacción de casos de prueba claros y escalables
# * Ejecución de pruebas manuales y automatizadas
# * Registro y documentación de bugs o anomalías detectadas

# %% [markdown]
# ## ¿Qué tipos de herramientas necesita un proyecto de QA?

# %% [markdown]
# * Gestión de pruebas (Test Management)
# * Automatización de pruebas
# * Gestión de errores o bugs
# * Integración con CI/CD y DevOps
# * Visualización y reportes

# %% [markdown]
# ## Herramientas de automatización de pruebas

# %% [markdown]
# | Herramienta | Testing funcional | Testing de regresión | Testing de performance | Testing de accesibilidad | Lenguajes/Frameworks soportados | Observaciones |
# |-------------|-------------------|----------------------|------------------------|--------------------------|---------------------------------|---------------|
# | Selenium    | ✔️                | ✔️                   | ❌                     | ❌                       | Java, Python, C#, Ruby          | Amplio soporte para navegadores, estándar en QA web |
# | Cypress     | ✔️                | ✔️                   | ❌                     | ❌                       | JavaScript, TypeScript          | Ideal para aplicaciones modernas front-end, rápido y confiable |
# | Playwright  | ✔️                | ✔️                   | ❌                     | ❌                       | JavaScript, Python, C#, Java    | Testing multi-navegador, soporte para escenarios complejos |
# | JMeter      | ❌                | ❌                   | ✔️                     | ❌                       | Java                            | Focalizado en pruebas de carga y stress |
# | Locust      | ❌                | ❌                   | ✔️                     | ❌                       | Python                          | Simulación de usuarios concurrentes, escalable |
# | Axe-core    | ❌                | ❌                   | ❌                     | ✔️                       | JavaScript                      | Librería para evaluar accesibilidad digital (WCAG) |
# | Puppeteer   | ✔️                | ✔️                   | ❌                     | ❌                       | JavaScript                      | Automatización de Chrome/Chromium, útil para scraping y testing |
# | TestCafe    | ✔️                | ✔️                   | ❌                     | ❌                       | JavaScript, TypeScript          | Fácil de configurar, testing end-to-end |
#
# ...

# %% [markdown]
# ## Elección de la mejor herramienta de automatización de pruebas

# %% [markdown]
# 1. Conocer a fondo los requisitos del proyecto
#     * ¿Qué problemas estoy tratando de resolver con una herramienta de automatización?
#     * ¿Qué tipo de pruebas se deben realizar?
#     * ¿Qué tipo de aplicación debe probarse?
#     * ¿En qué idioma está integrada la aplicación?
#     * ¿En qué sistemas operativos se debe probar?

# %% [markdown]
# 2. Evaluar las coding skills de los testers
#     * Conocer la habilidad técnica y la experiencia del equipo de pruebas

# %% [markdown]
# 3. Definir el presupuesto del proyecto
#     * Costo de comprar y mantener una herramienta de automatización
#     * Inversión en capacitación
#     * Contratar profesionales con experiencia

# %% [markdown]
# 4. Investigar el tipo de herramientas disponibles en el mercado
#     * Herramientas basadas en código y sin codigo
#     * Herramientas comerciales, open source
#     * Herramientas desktop, móviles y web

# %% [markdown]
# 5. Probar herramientas y no tener miedo de cambiar

# %% [markdown]
# ## Recursos

# %% [markdown]
# * [abstracta - Servicios de Ingenieria de Calidad](https://abstracta.us/es/)
# * ...
