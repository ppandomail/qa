# %% [markdown]
# # Externalización de datos
# ---

# %% [markdown]
# * Externalizar los datos de entrada del test a un archivo
# * El objetivo es desacoplar/deshardcodear los datos que consume la clase test, esto nos permite tener mayor legibilidad y hace mas simple el mantenimiento
# * Instalar la libreria: pyaml_env

# %%
# %%file test_login_data.py
import pytest
from selenium import webdriver
from page_login import PageLogin
from page_secure import PageSecure
from pyaml_env import parse_config

@pytest.fixture
def driver():
    driver = webdriver.Chrome()
    driver.get("https://the-internet.herokuapp.com/login")
    yield driver
    driver.quit()

@pytest.fixture
def class_setup(driver):
    page_login = PageLogin(driver)
    page_secure = PageSecure(driver)
    return page_login, page_secure

class TestLogin:

    data_login = parse_config('data_login.yaml')
    
    def test_login(self, class_setup):
        page_login, page_secure = class_setup
        page_login.write_username(self.data_login['username'])
        page_login.write_password(self.data_login['password'])
        page_login.click_login()
        assert page_secure.text_msg() == self.data_login['expected']
# Out:
# Writing test_login_data.py

# %%
# !pytest test_login_data.py
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.12.7, pytest-7.4.4, pluggy-1.0.0
# rootdir: /Users/ppando/Materias/qa/doc
# plugins: Faker-37.3.0, mock-3.14.1, typeguard-4.4.4, anyio-4.2.0
# collected 1 item
#
# test_login_data.py .                                                     [100%]
#
# ============================== 1 passed in 5.56s ===============================
